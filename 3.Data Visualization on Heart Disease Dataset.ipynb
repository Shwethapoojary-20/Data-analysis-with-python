# %% [markdown]
# https://www.kaggle.com/datasets/fedesoriano/heart-failure-prediction

# %%
import numpy as np 
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.shape
# Out:
# (918, 12)

# %%
df.nunique()
# Out:
# Age                50
# Sex                 2
# ChestPainType       4
# RestingBP          67
# Cholesterol       222
# FastingBS           2
# RestingECG          3
# MaxHR             119
# ExerciseAngina      2
# Oldpeak            53
# ST_Slope            3
# HeartDisease        2
# dtype: int64

# %% [markdown]
# ## Distribution plot for numeric columns

# %%
sns.distplot(df['Age'], rug=True ,bins=30)
# Out:
# C:\Users\pooja\AppData\Local\Temp\ipykernel_7148\2112663202.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'], rug=True ,bins=30)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df['RestingBP'] , color='blue')
# Out:
# C:\Users\pooja\AppData\Local\Temp\ipykernel_7148\2920611639.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['RestingBP'] , color='blue')
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sns.boxplot(data=df ,x= 'Cholesterol') # to check the outliers
# Out:
# <Axes: xlabel='Cholesterol'>

# %%
sns.distplot(df['Cholesterol'] , color='blue')
# Out:
# C:\Users\pooja\AppData\Local\Temp\ipykernel_7148\3303408354.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Cholesterol'] , color='blue')
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sns.distplot(df['MaxHR'] , color='blue')
# Out:
# C:\Users\pooja\AppData\Local\Temp\ipykernel_7148\1276099882.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['MaxHR'] , color='blue')
# <Axes: xlabel='MaxHR', ylabel='Density'>

# %% [markdown]
# ## pie chart for categorical

# %%
df.groupby('Sex').size()
# Out:
# Sex
# F    193
# M    725
# dtype: int64

# %%
df.groupby('Sex').size().plot(kind='pie' , autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby('ChestPainType').size()
# Out:
# ChestPainType
# ASY    496
# ATA    173
# NAP    203
# TA      46
# dtype: int64

# %%
df.groupby('ChestPainType').size().plot(kind='pie' , autopct='%0.1f')
# Out:
# <Axes: >

# %%
 df.groupby('RestingECG').size().plot(kind='pie' , autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby('ST_Slope').size().plot(kind='pie' , autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby('HeartDisease').size().plot(kind='pie' , autopct='%0.1f')
# Out:
# <Axes: >

# %% [markdown]
# ## Violin plot

# %%
sns.violinplot(data=df, x='Age')
# Out:
# <Axes: xlabel='Age'>

# %%
sns.violinplot(data=df, y='Sex' , x='HeartDisease')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(data=df, y='Age' , x='HeartDisease')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.violinplot(data=df, y='Cholesterol' , x='HeartDisease')
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# ## Correlation

# %% [markdown]
# Correlation is a statistical measure that describes the degree to which two variables are linearly related to each other. In other words, it quantifies the strength and direction of the relationship between two variables.
#
# The correlation coefficient, often denoted as r, ranges from -1 to 1:
#
# r=1: Perfect positive correlation. It indicates that as one variable increases, the other variable also increases proportionally.
#
# r=−1: Perfect negative correlation. It indicates that as one variable increases, the other variable decreases proportionally.
#
# r=0: No correlation. There is no linear relationship between the two variables.
#
# A correlation close to 1 or -1 suggests a strong linear relationship between the variables,
# while a correlation close to 0 suggests a weak or no linear relationship.

# %%
df.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %% [markdown]
# ### Heatmap

# %%
cor_mat= df.corr(numeric_only=True)
cor_mat
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(cor_mat, cmap='coolwarm', annot=True, fmt=".2f", linewidths=.5)
# Out:
# <Axes: >

# %% [markdown]
# ### JointPlot

# %%
sns.jointplot(data=df , x='Age' , y='MaxHR')

# %%
sns.jointplot(data=df , x='Age' , y='Age')

# %%
sns.jointplot(data=df , x='HeartDisease' , y='Oldpeak')

# %%
sns.jointplot(data=df , x='Cholesterol' , y='Oldpeak')

# %%
sns.jointplot(data=df , x='Age' , y='MaxHR' , kind='reg')

# %%
sns.jointplot(data=df , y='MaxHR' , x='HeartDisease' , kind='reg')

# %% [markdown]
# ### Pairplot

# %% [markdown]
# A pair plot is a type of plot in data visualization that displays pairwise relationships among multiple variables in a dataset. It's a grid of subplots where each variable in the dataset is plotted against every other variable.

# %%
sns.pairplot(df)
# Out:
# C:\Users\pooja\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
